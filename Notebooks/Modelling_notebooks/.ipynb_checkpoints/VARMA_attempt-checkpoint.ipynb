# %%
from statsmodels.tsa.statespace.varmax import VARMAX
from random import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import seaborn as sb
from scipy.stats import pearsonr
from sklearn.metrics import mean_squared_error

import sys
sys.path.insert(1, '../Merging_Data')

from sklearn.preprocessing import MinMaxScaler

import WranglerFunctions as wf
import FullDataset as fd
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %%
RIO_full = fd.GetFullDatasetForCompany("RIO LN Equity")
RIO_full.index = RIO_full['Date']
RIO_full = RIO_full.drop('Date', axis = 1)

def calculate_pvalues(df):
    df = df.dropna()._get_numeric_data()
    dfcols = pd.DataFrame(columns=df.columns)
    pvalues = dfcols.transpose().join(dfcols, how='outer')
    for r in df.columns:
        for c in df.columns:
            pvalues[r][c] = round(pearsonr(df[r], df[c])[1], 4)
    return pvalues

corr = RIO_full.corr()
discardedColumns = []
for column_idx in range(1, len(RIO_full.columns)):
    for row_idx in range (1, len(RIO_full.columns)):
        if (row_idx != column_idx):
            if (corr[corr.columns[column_idx]].loc[corr.columns[row_idx]] > 0.8):
                if (abs(corr['EBITDA'].loc[corr.columns[column_idx]]) > abs(corr['EBITDA'].loc[corr.columns[row_idx]])):
                    if (not corr.columns[row_idx] in discardedColumns):
                        discardedColumns.append(corr.columns[row_idx])
                else:
                    if (not corr.columns[column_idx] in discardedColumns):
                        discardedColumns.append(corr.columns[column_idx])
        else:
            break

RIO_removedInterCorrelation = RIO_full.drop(discardedColumns, axis = 1)
plt.subplots(figsize=(20,15))
ax = plt.axes()
ax.set_title("RIO LN Equity")

pvalues = calculate_pvalues(RIO_removedInterCorrelation)
statisticallySignificant = pvalues <= 0.05
discardedColumns = statisticallySignificant[statisticallySignificant['EBITDA'].values == False].index
RIO_final = RIO_removedInterCorrelation.drop(discardedColumns, axis = 1)
heatmap = sb.heatmap(RIO_final.corr(), cmap="YlGnBu", annot=True)
# Out:
# C:\Users\vojno\OneDrive - University of Bristol\Applied Data Science\Mining\Notebooks\Modelling_notebooks\../Merging_Data\WranglerFunctions.py:138: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(location   , index_col=False, names=["Dates", "PX_LAST"])
# C:\Users\vojno\OneDrive - University of Bristol\Applied Data Science\Mining\Notebooks\Modelling_notebooks\../Merging_Data\WranglerFunctions.py:138: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(location   , index_col=False, names=["Dates", "PX_LAST"])
# C:\Users\vojno\OneDrive - University of Bristol\Applied Data Science\Mining\Notebooks\Modelling_notebooks\../Merging_Data\FullDataset.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
def show_graph(df1, df2, title):
    data = pd.concat([df1, df2])
    data.reset_index(inplace=True, drop=True)
    for col in data.columns:
        if col.lower().startswith('pred'):
            data[col].plot(label=col,linestyle="dotted")
        else: 
            if col == "EBITDA":
                data[col].plot(label=col)
            elif col == "Actual":
                data[col].plot(label=col)
    plt.title(title)
    plt.legend()
    plt.show()

# %%
def VARMA_model(train,test, p, q):
    # fit model
    model = VARMAX(train, order=(p, q))
    model_fit = model.fit(disp=False)
    print(model_fit.summary())
    # make prediction
    yhat = model_fit.forecast(steps=len(test))
    res=pd.DataFrame({"Pred1":yhat['EBITDA'], "Actual":test['EBITDA'].values})
    return res

def return_yhat(main_df,train_df,test_df):
        y_hat_array = np.array([])
        EBITDA  = main_df[main_df.columns[0]]
        LMCADS03 = main_df[main_df.columns[1]]
        LMNIDS03 = main_df[main_df.columns[2]]
        LTBMPRIN = main_df[main_df.columns[3]]
        IR = main_df[main_df.columns[4]]
        SPX500_LAST = main_df[main_df.columns[5]]
        SPX500_VOLUME = main_df[main_df.columns[6]]
        GUKG10 = main_df[main_df.columns[7]]
        SHIP = main_df[main_df.columns[8]]
#         intercept = 0.4109 #for p= 2, q = 5
        #intercept = 0.4191 # fot p =1 , q=5 
        #intercept = 0.4202 #for p=1, q=2
        intercept = 0.3954 #for p=2, q=1
        #intercept = 0.4179 #for p=2, q=2
              
        for period in range(len(train_df),(len(train_df)+len(test_df)),1):
            y_hat = intercept + EBITDA[period-1]*(-0.0146) + LMCADS03[period-1]*(0.0184) + LTBMPRIN[period-1]*(0.1824) + IR[period-1]*(0.0462) + SPX500_LAST[period-1]*(0.0094) + GUKG10[period-1]*(-0.0325) + LMNIDS03[period-2]*(0.0305) + LTBMPRIN[period-2]*(-0.0116) + SPX500_LAST[period-2]*(0.0064)
#             y_hat = intercept + EBITDA[period-1]*(-0.0118) + LMCADS03[period-1]*(0.0308) + LTBMPRIN[period-1]*(0.2145) + IR[period-1]*(0.0103) + SPX500_LAST[period-1]*(0.0068) + SPX500_VOLUME[period-1]*(-0.0108) + GUKG10[period-1]*(-0.0102) + SHIP[period-1]*(-0.1044)
#             y_hat = intercept + EBITDA[period-1]*(-0.0082) + LMCADS03[period-1]*(-0.0061) + LMNIDS03[period-1]*(-0.0250) + IR[period-1]*(-0.0759) + SPX500_LAST[period-1]*(-0.0410) + SPX500_VOLUME[period-1]*(-0.0372) + GUKG10[period-1]*(0.1117) + SHIP[period-1]*(-0.0509) 
#             y_hat = intercept + LMCADS03[period-1]*(0.0238) + LMNIDS03[period-1]*(0.1057)+ LTBMPRIN[period-1]*(-0.0340) + IR[period-1]*(0.0440) + SPX500_LAST[period-1]*(-0.5200) + SPX500_VOLUME[period-1]*(-0.0518) + SHIP[period-1]*(-0.2105) + EBITDA[period-2]*(0.0773) + LMCADS03[period-2]*(0.0226) + LMNIDS03[period-2]*(0.0861)+ LTBMPRIN[period-2]*(0.0414) + IR[period-2]*(0.0553) + SPX500_LAST[period-2]*(-0.4352) + SPX500_VOLUME[period-2]*(-0.0442) + SHIP[period-2]*(-0.3118)
#             y_hat = intercept + GUKG10[period-1]*(0.0113)  + SHIP[period-1]*(-0.0077) + LMCADS03[period-2]*(-0.0074) + LMNIDS03[period-2]*(0.0421)+ LTBMPRIN[period-2]*(-0.0149) + IR[period-2]*(0.0209) + GUKG10[period-2]*(-0.0208)  + SHIP[period-2]*(0.0092)
#             y_hat = intercept + EBITDA[period - 1] * (0.0076) + LMCADS03[period - 1]*(0.0238) + LMNIDS03[period - 1]*(0.1057) + LTBMPRIN[period - 1] * (-0.0340) + IR[period - 1] * (0.0440) + SPX500_LAST[period - 1] * (-0.52) + SPX500_VOLUME[period - 1] * (-0.0518) + GUKG10[period - 1] * (-0.0014) + SHIP[period - 1] * (-0.2105) + EBITDA[period - 2] * (0.0773) + LMCADS03[period - 2]*(0.0226) + LMNIDS03[period - 2]*(0.0861) + LTBMPRIN[period - 2] * (0.0414) + IR[period - 2] * (0.0553) + SPX500_LAST[period - 2] * (-0.4352) + SPX500_VOLUME[period - 2] * (-0.0442) + GUKG10[period - 2] * (0.0058) + SHIP[period - 2] * (-0.3118)
            y_hat_array = np.append(y_hat_array,y_hat)
        print("length of pred = "+str(len(y_hat_array)))
        print("length of actual = "+str(len(test_df['EBITDA'].values)))
        res=pd.DataFrame({"Pred1":y_hat_array, "Actual":test_df['EBITDA'].values})
        return res

scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(RIO_final.values)

scaled_df = pd.DataFrame(scaled, columns = RIO_final.columns)


df_train = scaled_df.head(30)
df_test = scaled_df.tail(12)
#print(df_train['EBITDA'])
#print(df_test['EBITDA'])

#print(df_train)

# %%
#print(df_train[df_train.columns[0]])
manual_res = return_yhat(scaled_df,df_train,df_test)
print(manual_res)
# Out:
# length of pred = 12
# length of actual = 12
#        Pred1    Actual
# 0   0.423347  0.347307
# 1   0.436088  0.404223
# 2   0.494176  0.513367
# 3   0.547838  0.554281
# 4   0.574694  0.630570
# 5   0.615810  0.564626
# 6   0.591100  0.748431
# 7   0.533710  0.520651
# 8   0.514071  0.563503
# 9   0.472397  0.542735
# 10  0.454728  0.745138
# 11  0.459064  1.000000

# %%
num_lags=round((len(df_train)/2)-1.5)
plot_pacf(df_train['EBITDA'],lags = num_lags)
plt.show()

# %%
#ACF for the Moving Average q value
plot_acf(df_train['EBITDA'],lags = num_lags)
plt.show()

# %%
#for p in range(1, ):
#for q in range(1, 21):
p = 2
q = 1
print(p)
print(q)
# df_ret = VARMA_model(df_train, df_test, p, q)
show_graph(df_train, manual_res, "Vector Autoregression Moving-Average (VARMA)")
rmse_AllFeatures = mean_squared_error(manual_res['Actual'], manual_res['Pred1'], squared = False)
rmse_AllFeatures
# Out:
# 2
# 1
# 0.18757515361068425

# %% [markdown]
# ## Running VARMA with important features

# %%
def return_yhat_removing_feature(main_df,train_df,test_df, i):
        y_hat_array = np.array([])
        EBITDA  = main_df[main_df.columns[0]]
        LMCADS03 = main_df[main_df.columns[1]]
        LMNIDS03 = main_df[main_df.columns[2]]
        LTBMPRIN = main_df[main_df.columns[3]]
        IR = main_df[main_df.columns[4]]
        SPX500_LAST = main_df[main_df.columns[5]]
        SPX500_VOLUME = main_df[main_df.columns[6]]
        GUKG10 = main_df[main_df.columns[7]]
        SHIP = main_df[main_df.columns[8]]

        # For LMCADS03 removed:
#         intercept = 0.4261
        # For LMNIDS03 removed:
#         intercept = 0.4205
        # For LTBMPRIN removed:
#         intercept = 0.3972
        # For IR removed:
#         intercept = 0.4174
        # For SPX500_LAST removed:
#         intercept = 0.4062
        # For SPX500_VOLUME removed:
#         intercept = 0.4239
        # For GUKG10 removed:
#         intercept = 0.4205
        # For SHIP removed:
#         intercept = 0.4260
        
        for period in range(len(train_df),(len(train_df)+len(test_df)),1):
            if i == 1:
        # Below y_hat is for first column removed
                intercept = 0.4261
                y_hat = intercept + EBITDA[period - 1] * (-0.2183) + LMNIDS03[period - 1]*(0.3904) + LTBMPRIN[period - 1] * (4.0884) + IR[period - 1] * (0.0869) + SPX500_LAST[period - 1] * (-1.7250) + SPX500_VOLUME[period - 1] * (-0.3067) + GUKG10[period - 1] * (-0.0248) + SHIP[period - 1] * (-0.8882) + EBITDA[period - 2] * (-0.0445) + LMNIDS03[period - 2]*(0.2375) + LTBMPRIN[period - 2] * (3.4769) + IR[period - 2] * (0.1223) + SPX500_LAST[period - 2] * (-0.7943) + SPX500_VOLUME[period - 2] * (-0.1323) + GUKG10[period - 2] * (-0.0233) + SHIP[period - 2] * (-0.0864)
            if i == 2:
        # Below y_hat is for second column removed
                intercept = 0.4205
                y_hat = intercept + EBITDA[period - 1] * (0.0048) + LMCADS03[period - 1]*(0.0007) + LTBMPRIN[period - 1] * (0.5328) + IR[period - 1] * (0.0891) + SPX500_LAST[period - 1] * (-0.0179) + SPX500_VOLUME[period - 1] * (-0.0442) + GUKG10[period - 1] * (0.0184) + SHIP[period - 1] * (-1.1872) + EBITDA[period - 2] * (-0.0528) + LMCADS03[period - 2]*(0.1257) + LTBMPRIN[period - 2] * (1.5401) + IR[period - 2] * (-0.1408) + SPX500_LAST[period - 2] * (-0.4738) + SPX500_VOLUME[period - 2] * (-0.0057) + GUKG10[period - 2] * (0.0411) + SHIP[period - 2] * (0.3437)
            if i == 3:
        # Below y_hat is for third column removed
                intercept = 0.3972
                y_hat = intercept + EBITDA[period - 1] * (0.0680) + LMCADS03[period - 1]*(-0.0808) + LMNIDS03[period - 1] * (0.0765) + IR[period - 1] * (-0.0304) + SPX500_LAST[period - 1] * (-0.2231) + SPX500_VOLUME[period - 1] * (-0.1129) + GUKG10[period - 1] * (0.0494) + SHIP[period - 1] * (-0.0137) + EBITDA[period - 2] * (0.0355) + LMCADS03[period - 2]*(0.0367) + LMNIDS03[period - 2] * (0.0662) + IR[period - 2] * (0.0040) + SPX500_LAST[period - 2] * (0.1061) + SPX500_VOLUME[period - 2] * (-0.0022) + GUKG10[period - 2] * (-0.0467) + SHIP[period - 2] * (-0.0213)
            if i == 4:
        # Below y_hat is for fourth column removed
                intercept = 0.4174
                y_hat = intercept + EBITDA[period - 1] * (-0.0070) + LMCADS03[period - 1]*(0.0007) + LMNIDS03[period - 1] * (0.0414) + LTBMPRIN[period - 1] * (-0.8968) + SPX500_LAST[period - 1] * (-0.0753) + SPX500_VOLUME[period - 1] * (-0.0346) + GUKG10[period - 1] * (-0.0562) + SHIP[period - 1] * (-0.0246) + EBITDA[period - 2] * (0.0139) + LMCADS03[period - 2]*(-0.0017) + LMNIDS03[period - 2] * (-0.0005) + LTBMPRIN[period - 2] * (-0.2896) + SPX500_LAST[period - 2] * (-0.0343) + SPX500_VOLUME[period - 2] * (0.0067) + GUKG10[period - 2] * (-0.0203) + SHIP[period - 2] * (-0.0299)
            if i == 5:
        # Below y_hat is for fifth column removed
                intercept = 0.4062
                y_hat = intercept + EBITDA[period - 1] * (-0.0080) + LMCADS03[period - 1]*(-0.0557) + LMNIDS03[period - 1] * (0.2165) + LTBMPRIN[period - 1] * (0.9744) + IR[period - 1] * (0.1331) + SPX500_VOLUME[period - 1] * (-0.0744) + GUKG10[period - 1] * (-0.0124) + SHIP[period - 1] * (-1.5383) + EBITDA[period - 2] * (-0.0473) + LMCADS03[period - 2]*(0.0050) + LMNIDS03[period - 2] * (0.0135) + LTBMPRIN[period - 2] * (1.0401) + IR[period - 2] * (0.0184) + SPX500_VOLUME[period - 2] * (-0.1255) + GUKG10[period - 2] * (0.0841) + SHIP[period - 2] * (-0.4686)
            if i == 6:
        # Below y_hat is for sixth column removed
                intercept = 0.4239
                y_hat = intercept + EBITDA[period - 1] * (0.0008) + LMCADS03[period - 1]*(0.0385) + LMNIDS03[period - 1] * (0.0165) + LTBMPRIN[period - 1] * (-0.0096) + IR[period - 1] * (0.0417) + SPX500_LAST[period - 1] * (-0.0231) + GUKG10[period - 1] * (-0.0795) + SHIP[period - 1] * (0.0274) + EBITDA[period - 2] * (0.0334) + LMCADS03[period - 2]*(-0.0245) + LMNIDS03[period - 2] * (0.0383) + LTBMPRIN[period - 2] * (-0.0112) + IR[period - 2] * (0.0100) + SPX500_LAST[period - 2] * (0.0173) + GUKG10[period - 2] * (-0.0086) + SHIP[period - 2] * (0.0040)
            if i == 7:
        # Below y_hat is for seventh column removed
                intercept = 0.4205
                y_hat = intercept + EBITDA[period - 1] * (0.0180) + LMCADS03[period - 1]*(-0.0597) + LMNIDS03[period - 1] * (0.0342) + LTBMPRIN[period - 1] * (-0.0356) + IR[period - 1] * (-0.0896) + SPX500_LAST[period - 1] * (-0.2282) + SPX500_VOLUME[period - 1] * (0.0570) + SHIP[period - 1] * (0.1211) + EBITDA[period - 2] * (-0.0230) + LMCADS03[period - 2]*(0.0306) + LMNIDS03[period - 2] * (0.0278) + LTBMPRIN[period - 2] * (0.0317) + IR[period - 2] * (-0.0969) + SPX500_LAST[period - 2] * (-0.0727) + SPX500_VOLUME[period - 2] * (0.0657) + SHIP[period - 2] * (0.0664)
            if i == 8:
        # Below y_hat is for eighth column removed
                intercept = 0.4260
                y_hat = intercept + EBITDA[period - 1] * (-0.1497) + LMCADS03[period - 1]*(0.4237) + LMNIDS03[period - 1] * (-1.1938) + LTBMPRIN[period - 1] * (-2.5539) + IR[period - 1] * (-0.3522) + SPX500_LAST[period - 1] * (0.8184) + SPX500_VOLUME[period - 1] * (-0.2110) + GUKG10[period - 1] * (-0.1735) + EBITDA[period - 2] * (0.0578) + LMCADS03[period - 2]*(-0.2993) + LMNIDS03[period - 2] * (0.3887) + LTBMPRIN[period - 2] * (2.2633) + IR[period - 2] * (-0.2236) + SPX500_LAST[period - 2] * (-1.5367) + SPX500_VOLUME[period - 2] * (-0.5746) + GUKG10[period - 2] * (-0.3029)

            y_hat_array = np.append(y_hat_array,y_hat)
        print("length of pred = "+str(len(y_hat_array)))
        print("length of actual = "+str(len(test_df['EBITDA'].values)))
        res=pd.DataFrame({"Pred1":y_hat_array, "Actual":test_df['EBITDA'].values})
        return res
    
df_train_removed = df_train.drop(df_train.columns[8], axis = 1)
df_test_removed = df_test.drop(df_test.columns[8], axis = 1)
# df_ret = VARMA_model(df_train_removed, df_test_removed, p, q)

# %%
# manual_res = return_yhat_removing_feature(scaled_df,df_train_removed,df_test_removed)
# show_graph(df_train_removed, manual_res, "Vector Autoregression Moving-Average (VARMA)")
# rmse_removedFeature = mean_squared_error(manual_res['Actual'], manual_res['Pred1'])
# rmse_removedFeature

# %%
def getAllRMSEOneFeatureRemoved(main_df, train_df, test_df):
    rmseList = []
    for i in range(1, len(main_df.columns)):
        df_train_removed = df_train.drop(df_train.columns[i], axis = 1)
        df_test_removed = df_test.drop(df_test.columns[i], axis = 1)
        manual_res = return_yhat_removing_feature(main_df, df_train_removed, df_test_removed, i)
        rmseList.append(mean_squared_error(manual_res['Actual'], manual_res['Pred1'], squared = True))
    return rmseList
rmseList = getAllRMSEOneFeatureRemoved(scaled_df, df_train, df_test)
# Out:
# length of pred = 12
# length of actual = 12
# length of pred = 12
# length of actual = 12
# length of pred = 12
# length of actual = 12
# length of pred = 12
# length of actual = 12
# length of pred = 12
# length of actual = 12
# length of pred = 12
# length of actual = 12
# length of pred = 12
# length of actual = 12
# length of pred = 12
# length of actual = 12

# %%
x = np.arange(len(scaled_df.columns) - 1)
ax1 = plt.subplot()
w = 0.3
#plt.xticks(), will label the bars on x axis with the respective country names.
plt.xticks(x + w /2, scaled_df.columns[1:], rotation='vertical')
modelAccuracy = ax1.bar(x, [abs(rmse - rmse_AllFeatures) for rmse in rmseList], width=w, color='b', align='center')
plt.ylabel("Difference between RMSE of model when feature is removed")
#The trick is to use two different axes that share the same x axis, we have used ax1.twinx() method.
ax2 = ax1.twinx()

correlation = ax2.bar(x + w, abs(scaled_df.corr()['EBITDA'][1:].values), width=w,color='r',align='center')

plt.ylabel("Absolute Pearson's correlation coefficient")
#To set the legend on the plot we have used plt.legend()
plt.legend([modelAccuracy, correlation],["RMSE difference", "Correlation coefficient"])
#To show the plot finally we have used plt.show().
plt.show()

# %%
zip_iterator = zip(scaled_df.columns[1:], abs(scaled_df.corr()['EBITDA'][1:].values))
corr_dict = dict(zip_iterator)
companyCorrSorted = sorted(corr_dict, key=corr_dict.get)

zip_iterator = zip(scaled_df.columns[1:], [abs(rmse - rmse_AllFeatures) for rmse in rmseList])
rmse_dict = dict(zip_iterator)
rmse_list_corr_order = []
for company in companyCorrSorted:
    rmse_list_corr_order.append(rmse_dict[company])


x = np.arange(len(scaled_df.columns) - 1)
ax1 = plt.subplot()
w = 0.3
#plt.xticks(), will label the bars on x axis with the respective country names.
plt.xticks(x + w /2, companyCorrSorted, rotation='vertical')
modelAccuracy = ax1.bar(x, rmse_list_corr_order, width=w, color='b', align='center')
plt.ylabel("Difference between RMSE of model when feature is removed")
#The trick is to use two different axes that share the same x axis, we have used ax1.twinx() method.
ax2 = ax1.twinx()

correlation = ax2.bar(x + w, sorted(abs(scaled_df.corr()['EBITDA'][1:].values)), width=w,color='r',align='center')

plt.ylabel("Absolute Pearson's correlation coefficient")
#To set the legend on the plot we have used plt.legend()
plt.legend([modelAccuracy, correlation],["RMSE difference", "Correlation coefficient"])
#To show the plot finally we have used plt.show().
plt.show()

# %% [markdown]
# #### We conclude that LMCADS03 is the best indicator.
