# %%
import pandas as pd
import matplotlib.pyplot as plt

from datetime import datetime

# %%
original_data = pd.read_csv('../../Notebooks/Datasets/Economic_dataset/Economic_Events.csv')
original_data
# Out:
#             Date Time Unnamed: 1 Unnamed: 2  Unnamed: 3  \
# 0    01/07/2016 19:01         UK         1)         NaN
# 1          01/08/2016         UK         2)         NaN
# 2    01/12/2016 09:15         UK         3)         NaN
# 3    01/12/2016 11:00         UK         4)         NaN
# 4    01/14/2016 05:30         UK         5)         NaN
# ..                ...        ...        ...         ...
# 775  11/30/2021 08:00         UK       776)         NaN
# 776  12/01/2021 09:00         UK       777)         NaN
# 777  12/03/2021 06:00         UK       778)         NaN
# 778        12/10/2021         UK       779)         NaN
# 779  01/28/2022 04:30         UK       780)         NaN
#
#                                                  Event
# 0    Jonathan Hill meets with Jon Cunliffe, Deputy ...
# 1    United Kingdom Sovereign Debt to Be Rated by DBRS
# 2                          Mark Carney speaks in Paris
# 3    Cameron Questioned by Commons Panel on Syria, ...
# 4    Andrew Bailey Speaks on Green Finance at Mansi...
# ..                                                 ...
# 775           BOE's Mann speaks at event with Barclays
# 776        BOE's Bailey speaks on insurance regulation
# 777                             BOE's Saunders speaks.
# 778  United Kingdom Sovereign Debt to be rated by F...
# 779                      Inflation by household income
#
# [780 rows x 5 columns]

# %% [markdown]
# ## Data Wrangling

# %%
clean_data = original_data.drop(labels = ['Unnamed: 2', 'Unnamed: 3'], axis = 1)
clean_data
# Out:
#             Date Time Unnamed: 1  \
# 0    01/07/2016 19:01         UK
# 1          01/08/2016         UK
# 2    01/12/2016 09:15         UK
# 3    01/12/2016 11:00         UK
# 4    01/14/2016 05:30         UK
# ..                ...        ...
# 775  11/30/2021 08:00         UK
# 776  12/01/2021 09:00         UK
# 777  12/03/2021 06:00         UK
# 778        12/10/2021         UK
# 779  01/28/2022 04:30         UK
#
#                                                  Event
# 0    Jonathan Hill meets with Jon Cunliffe, Deputy ...
# 1    United Kingdom Sovereign Debt to Be Rated by DBRS
# 2                          Mark Carney speaks in Paris
# 3    Cameron Questioned by Commons Panel on Syria, ...
# 4    Andrew Bailey Speaks on Green Finance at Mansi...
# ..                                                 ...
# 775           BOE's Mann speaks at event with Barclays
# 776        BOE's Bailey speaks on insurance regulation
# 777                             BOE's Saunders speaks.
# 778  United Kingdom Sovereign Debt to be rated by F...
# 779                      Inflation by household income
#
# [780 rows x 3 columns]

# %% [markdown]
# Some formats of Date Time are not correct:

# %% [markdown]
# Column Date Time needs to be formatted correctly

# %% [markdown]
# Below is converting date times from string to datetime format

# %%
count = 0
for i in range(len(clean_data)):
    try:
        clean_data['Date Time'][i] = pd.to_datetime(clean_data['Date Time'][i])
    except ValueError:
        count += 1
print(count)
# Out:
# 24

# %% [markdown]
# Below are cells which are not formatted properly - mostly indicating when the event finished

# %%
clean_data[clean_data['Date Time'].apply(lambda x: isinstance(x, str))]
# Out:
#             Date Time Unnamed: 1  \
# 8    01/25/2016 01/26         UK
# 67   05/11/2016 05/12         UK
# 75   05/20/2016 05/21         GE
# 103  07/08/2016 07/11         CH
# 104  07/11/2016 07/17         UK
# 125  09/03/2016 09/05         CH
# 152  10/18/2016 10/19         UK
# 173  11/17/2016 11/19         GE
# 174  11/17/2016 11/18         US
# 195  01/13/2017 01/18         US
# 200  01/17/2017 01/19         UK
# 209  02/05/2017 02/06         UK
# 210  02/06/2017 02/08         UK
# 261  06/11/2017 06/12         IT
# 275  07/09/2017 07/10         AU
# 298  09/28/2017 09/29         UK
# 337  11/14/2017 11/15         UK
# 349  12/14/2017 12/16         CH
# 394  05/02/2018 05/04         EC
# 405  05/31/2018 06/02         CA
# 426  07/21/2018 07/22         AR
# 428  07/27/2018 07/29         AR
# 514  06/08/2019 06/09         UK
# 537  07/22/2019 07/28         UK
#
#                                                  Event
# 8    Middle East & North Africa Energy Conference H...
# 67                                 EBRD Annual Meeting
# 75   G-7 Finance Ministers, Central Bank Governors ...
# 103              G-20 Trade Ministers Meet in Shanghai
# 104    Farnborough International Airshow Features F-35
# 125               G-20 Leaders Meet in Hangzhou, China
# 152  Saudi Oil Minister to Attend Oil & Money Confe...
# 173  Valls, Sturgeon, Schaeuble at Economic Confere...
# 174  President Obama Meets With Chancellor Merkel a...
# 195  Secretary Kerry Travels to Vietnam, France, U....
# 200           Secretary Boris Johnson Travels to India
# 209  U.K. Prime Minister May to Meet Israel's Netan...
# 210  U.K. House of Commons Completes Debate on Arti...
# 261             G7 Environment Ministers Meet in Italy
# 275    Prime Minister May Host Prime Minister Turnbull
# 298  Carney Speaks at BOE Independence Conference, ...
# 337  European Union Withdrawal Bill Examination Begins
# 349  China, U.K. Hold Economic and Financial Dialog...
# 394  EU, U.K. Negotiators Begin Next Round of Brexi...
# 405  G-7 Finance Ministers and Central Bankers Meet...
# 426  G-20 Finance Ministers, Central Bankers Meet i...
# 428   G-20 Agricultural Ministers Meet in Buenos Aires
# 514  Chancellor Philip Hammond attends G20 Finance ...
# 537  Conservatives to name new Prime Minister after...
